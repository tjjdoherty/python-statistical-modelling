# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
# imports

import requests
import json # in vscode, this import is needed to parse the JSON from the api call
import pandas as pd
import numpy as np

# from IPython.display import JSON # for nice JSON (or dict) display in JupyterLab (not currently supported in Jupyter Notebook)

# %% [markdown]
# Contact the server via an API call
#
# API Details (Added by my for reference): https://api.citybik.es/v2/

# %%
# set city for investigation - Toronto AKA Bike Share Toronto
city_name = "Toronto, ON"

# get network response for all bike share networks in the world first
response = requests.request('GET', url="https://api.citybik.es/v2/networks")
data_networks = response.json()

# normalize it into a dataframe
df_networks_raw = pd.json_normalize(data_networks['networks'])
df_networks_raw
# Out:
#                                                company  \
# 0                                     [ЗАО «СитиБайк»]
# 1                                  [Comunicare S.r.l.]
# 2                                 [Cyclopolis Systems]
# 3                                 [Cyclopolis Systems]
# 4                                  [Comunicare S.r.l.]
# ..                                                 ...
# 785                                        [PickeBike]
# 786  [Mobilitätsakademie AG, Touring Club Switzerla...
# 787                                        [PickeBike]
# 788                                        [PickeBike]
# 789                         [LastenVelo Freiburg e.V.]
#
#                                                   href  \
# 0                         /v2/networks/velobike-moscow
# 1                        /v2/networks/bicincitta-siena
# 2                     /v2/networks/cyclopolis-maroussi
# 3                      /v2/networks/cyclopolis-nafplio
# 4    /v2/networks/bicincitta-parco-dei-colli-di-ber...
# ..                                                 ...
# 785                     /v2/networks/pickebike-aubonne
# 786                               /v2/networks/carvelo
# 787                       /v2/networks/pickebike-basel
# 788                    /v2/networks/pickebike-fribourg
# 789                   /v2/networks/lastenvelo-freiburg
#
#                                         id                         name  \
# 0                          velobike-moscow                     Velobike
# 1                         bicincitta-siena                   Bicincittà
# 2                      cyclopolis-maroussi                   Cyclopolis
# 3                       cyclopolis-nafplio                   Cyclopolis
# 4    bicincitta-parco-dei-colli-di-bergamo                   Bicincittà
# ..                                     ...                          ...
# 785                      pickebike-aubonne            PickeBike Aubonne
# 786                                carvelo  carvelo eCargo-Bike Sharing
# 787                        pickebike-basel              PickeBike Basel
# 788                     pickebike-fribourg           PickeBike Fribourg
# 789                    lastenvelo-freiburg          LastenVelo Freiburg
#
#                   location.city location.country  location.latitude  \
# 0                        Moscow               RU          55.750000
# 1                         Siena               IT          43.318600
# 2                      Maroussi               GR          38.056872
# 3                       Nafplio               GR          37.563940
# 4    Parco dei Colli di Bergamo               IT          45.722956
# ..                          ...              ...                ...
# 785                     Aubonne               CH          46.494900
# 786                 Switzerland               CH          46.982900
# 787                       Basel               CH          47.557900
# 788                    Fribourg               CH          46.803900
# 789                    Freiburg               DE          47.998100
#
#      location.longitude                                             source  \
# 0             37.616667                                                NaN
# 1             11.330600  https://www.bicincitta.com/frmLeStazioni.aspx?...
# 2             23.808330                                                NaN
# 3             22.809340                                                NaN
# 4              9.649230  https://www.bicincitta.com/frmLeStazioni.aspx?...
# ..                  ...                                                ...
# 785            6.396300  https://github.com/SFOE/sharedmobility/blob/ma...
# 786            8.233100  https://github.com/SFOE/sharedmobility/blob/ma...
# 787            7.590200  https://github.com/SFOE/sharedmobility/blob/ma...
# 788            7.150500  https://github.com/SFOE/sharedmobility/blob/ma...
# 789            7.843900                                                NaN
#
#                                              gbfs_href ebikes license.name  \
# 0                                                  NaN    NaN          NaN
# 1                                                  NaN    NaN          NaN
# 2                                                  NaN    NaN          NaN
# 3                                                  NaN    NaN          NaN
# 4                                                  NaN    NaN          NaN
# ..                                                 ...    ...          ...
# 785  https://gbfs.prod.sharedmobility.ch/v2/gbfs/pi...    NaN     Open Use
# 786  https://gbfs.prod.sharedmobility.ch/v2/gbfs/ca...    NaN     Open Use
# 787  https://gbfs.prod.sharedmobility.ch/v2/gbfs/pi...    NaN     Open Use
# 788  https://gbfs.prod.sharedmobility.ch/v2/gbfs/pi...    NaN     Open Use
# 789                                                NaN    NaN          NaN
#
#                                            license.url
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 785  https://opendata.swiss/en/dataset/standorte-un...
# 786  https://opendata.swiss/en/dataset/standorte-un...
# 787  https://opendata.swiss/en/dataset/standorte-un...
# 788  https://opendata.swiss/en/dataset/standorte-un...
# 789                                                NaN
#
# [790 rows x 13 columns]

# %% [markdown]
# 790 Cities in lots of countries, I want to find Toronto, Canada

# %%
# Country is a two letter symbol so search Canada with CA
df_networks_raw[df_networks_raw['location.country'] == 'CA']

# Toronto is found under 'Toronto, ON' not 'Toronto'
# Out:
#                                                company  \
# 70   [Motivate International, Inc., PBSC Urban Solu...
# 72   [Motivate International, Inc., PBSC Urban Solu...
# 73                              [Social Bicycles Inc.]
# 199  [Vanncouver Bike Share Inc., CycleHop LLC, Cit...
# 504                             [PBSC Urban Solutions]
# 505                             [PBSC Urban Solutions]
#
#                                  href                   id  \
# 70         /v2/networks/bixi-montreal        bixi-montreal
# 72          /v2/networks/bixi-toronto         bixi-toronto
# 73         /v2/networks/sobi-hamilton        sobi-hamilton
# 199            /v2/networks/mobibikes            mobibikes
# 504         /v2/networks/avelo-quebec         avelo-quebec
# 505  /v2/networks/acces-velo-saguenay  acces-velo-saguenay
#
#                    name location.city location.country  location.latitude  \
# 70                 Bixi  Montréal, QC               CA          45.508693
# 72   Bike Share Toronto   Toronto, ON               CA          43.653226
# 73                 SoBi  Hamilton, ON               CA          43.256436
# 199                Mobi     Vancouver               CA          49.282700
# 504               àVélo        Québec               CA          46.813050
# 505          Accès Vélo      Saguenay               CA          48.433333
#
#      location.longitude source  \
# 70           -73.553928    NaN
# 72           -79.383184    NaN
# 73           -79.869297    NaN
# 199         -123.120700    NaN
# 504          -71.216800    NaN
# 505          -71.083333    NaN
#
#                                              gbfs_href ebikes license.name  \
# 70            https://gbfs.velobixi.com/gbfs/gbfs.json   True          NaN
# 72       https://tor.publicbikesystem.net/ube/gbfs/v1/    NaN          NaN
# 73   https://hamilton.socialbicycles.com/opendata/g...    NaN          NaN
# 199  https://vancouver-gbfs.smoove.pro/gbfs/2/gbfs....    NaN          NaN
# 504  https://quebec.publicbikesystem.net/customer/g...    NaN          NaN
# 505  https://saguenay.publicbikesystem.net/customer...    NaN          NaN
#
#     license.url
# 70          NaN
# 72          NaN
# 73          NaN
# 199         NaN
# 504         NaN
# 505         NaN

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
# we have the href for toronto /v2/networks/bixi-toronto and according to api documentation we make the call by adding fields ?field=list,of,fields

href_toronto = "/v2/networks/bixi-toronto"

response = requests.request('GET', url="https://api.citybik.es/v2/networks/bixi-toronto?fields=stations")
data_stations = response.json()

# %% [markdown]
# **Note on CityBike API Call:**
# - Current call was made at 3pm on Saturday afternoon, early August
# - Warm clear weather, holiday weekend, lots of recreation going on
#
# - Secondary call made on holiday Monday at 1:30pm - most establishments (supermarkets, some cafes and bars/restaurants) closed, less downtown activity

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
df_toronto_stations = pd.json_normalize(data_stations['network']['stations'])
df_toronto_stations
# Out:
#      empty_slots  free_bikes                                id   latitude  \
# 0              1          18  fb337bbed72e2be090071e199899b2be  43.665269
# 1             10           4  4ff88d5880e71aa40d34cfe5d09b0ca7  43.671420
# 2              0          23  a09c67c0b419654d907c9134b108e328  43.666224
# 3             34           2  d6a9daee68070a8b106cfb598d81308c  43.653236
# 4             19          15  8f8af40d9388c8a3962559e8681d3db7  43.663722
# ..           ...         ...                               ...        ...
# 824           13           2  62acc308c0f93ff09d28e06c73afc3ec  43.705875
# 825           11           2  bea74af3bf338f6416944906b4b99d01  43.673489
# 826           14           1  452b30fbf0fc84eedbd3a7723bdafea0  43.601162
# 827           15           0  a8d19e5a065743874f30fd9cc5322947  43.727291
# 828           19           0  0f9fabd3b11f238b817673ee0162a944  43.740339
#
#      longitude                          name                    timestamp  \
# 0   -79.319796     Queen St E / Woodward Ave  2024-08-05T17:31:32.819000Z
# 1   -79.445947   Primrose Ave / Davenport Rd  2024-08-05T17:31:32.822000Z
# 2   -79.317693       Queen St E / Rhodes Ave  2024-08-05T17:31:32.850000Z
# 3   -79.376716          Bond St / Queen St E  2024-08-05T17:31:32.952000Z
# 4   -79.380288      Church St / Alexander St  2024-08-05T17:31:32.969000Z
# ..         ...                           ...                          ...
# 824 -79.368006                  165 McRae Dr  2024-08-05T17:31:33.260000Z
# 825 -79.413395        Albany Ave / Dupont St  2024-08-05T17:31:37.269000Z
# 826 -79.504160  Sixth St / Lake Shore Blvd W  2024-08-05T17:31:38.594000Z
# 827 -79.252379  Gordonridge Pl / Danforth Rd  2024-08-05T17:31:37.274000Z
# 828 -79.239353      McCowan Rd / Trudelle St  2024-08-05T17:31:37.360000Z
#
#                     extra.address  extra.altitude  extra.ebikes  \
# 0       Queen St E / Woodward Ave             0.0             2
# 1     Primrose Ave / Davenport Rd             0.0             1
# 2       Queen St. E / Rhodes Ave.             0.0             0
# 3            Bond St / Queen St E             0.0             0
# 4        Church St / Alexander St             0.0             0
# ..                            ...             ...           ...
# 824                  165 McRae Dr             0.0             0
# 825        Albany Ave / Dupont St             0.0             1
# 826                  131 Sixth St             0.0             0
# 827  Gordonridge Pl / Danforth Rd             0.0             0
# 828      McCowan Rd / Trudelle St             0.0             0
#
#      extra.has_ebikes  extra.last_updated  extra.normal_bikes  \
# 0                True          1722879012                  16
# 1                True          1722878987                   3
# 2                True          1722878955                  23
# 3                True          1722879026                   2
# 4                True          1722879049                  15
# ..                ...                 ...                 ...
# 824              True          1722878919                   2
# 825              True          1722878997                   1
# 826              True          1722878963                   1
# 827              True          1722878958                   0
# 828              True          1722878937                   0
#
#                              extra.payment  extra.payment-terminal  \
# 0    [key, transitcard, creditcard, phone]                    True
# 1    [key, transitcard, creditcard, phone]                    True
# 2    [key, transitcard, creditcard, phone]                    True
# 3    [key, transitcard, creditcard, phone]                    True
# 4    [key, transitcard, creditcard, phone]                    True
# ..                                     ...                     ...
# 824              [key, transitcard, phone]                   False
# 825              [key, transitcard, phone]                   False
# 826              [key, transitcard, phone]                   False
# 827              [key, transitcard, phone]                   False
# 828              [key, transitcard, phone]                   False
#
#      extra.renting  extra.returning  extra.slots extra.uid extra.post_code
# 0                1                1           19      7303             NaN
# 1                1                1           15      7301             NaN
# 2                1                1           23      7309             NaN
# 3                1                1           37      7045             NaN
# 4                1                1           35      7044             NaN
# ..             ...              ...          ...       ...             ...
# 824              1                1           15      7779         M4G 1S8
# 825              1                1           15      7966         M5R 3E1
# 826              1                1           15      7845         M8V 1J4
# 827              1                1           15      7967         M1K 4H6
# 828              1                1           19      7968         M1J 1J3
#
# [829 rows x 20 columns]

# %%
df_toronto_stations.shape
# Out:
# (829, 20)

# %%
# saving the df to csv so I can save the data retrieved
# csv_file_path = 'bike_stations_sat_3pm.csv'
# df_toronto_stations.to_csv(csv_file_path, index=False)

# %%
# extract the columns of interest into a new df to strip out the irrelevant/extra columns
df_toronto_stations = pd.read_csv('bike_stations_sat_3pm.csv')

df_toronto = df_toronto_stations[['id', 'name', 'latitude', 'longitude', 'free_bikes', 'empty_slots']]

df_toronto['bike_availability'] = round((df_toronto['free_bikes'] / (df_toronto['free_bikes'] + df_toronto['empty_slots'])) * 100, 2)

df_toronto['ll'] = round(df_toronto['latitude'], 6).astype(str) + ',' + round(df_toronto['longitude'], 6).astype(str)

df_toronto
# Out:
# <ipython-input-34-014f845d4ec3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_toronto['bike_availability'] = round((df_toronto['free_bikes'] / (df_toronto['free_bikes'] + df_toronto['empty_slots'])) * 100, 2)
# <ipython-input-34-014f845d4ec3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_toronto['ll'] = round(df_toronto['latitude'], 6).astype(str) + ',' + round(df_toronto['longitude'], 6).astype(str)
#                                    id  \
# 0    fb337bbed72e2be090071e199899b2be
# 1    4ff88d5880e71aa40d34cfe5d09b0ca7
# 2    a09c67c0b419654d907c9134b108e328
# 3    d6a9daee68070a8b106cfb598d81308c
# 4    8f8af40d9388c8a3962559e8681d3db7
# ..                                ...
# 821  9be5f078a1ed47fc11cd3cee45260f63
# 822  4ae37f3bddfb819954a15143d277dbd9
# 823  e7968ab22d9a15db0673f463144428eb
# 824  62acc308c0f93ff09d28e06c73afc3ec
# 825  bea74af3bf338f6416944906b4b99d01
#
#                                              name   latitude  longitude  \
# 0                       Queen St E / Woodward Ave  43.665269 -79.319796
# 1                     Primrose Ave / Davenport Rd  43.671420 -79.445947
# 2                         Queen St E / Rhodes Ave  43.666224 -79.317693
# 3                            Bond St / Queen St E  43.653236 -79.376716
# 4                        Church St / Alexander St  43.663722 -79.380288
# ..                                            ...        ...        ...
# 821  Kennedy Rd/Ranstone Gdns (Jack Goodlad Park)  43.741906 -79.271819
# 822                   Eglinton Ave E / Brimley Rd  43.736953 -79.247984
# 823                            College Park South  43.659457 -79.382365
# 824                                  165 McRae Dr  43.705875 -79.368006
# 825                        Albany Ave / Dupont St  43.673489 -79.413395
#
#      free_bikes  empty_slots  bike_availability                    ll
# 0            18            1              94.74  43.665269,-79.319796
# 1             1           14               6.67   43.67142,-79.445947
# 2            12           11              52.17  43.666224,-79.317693
# 3             5           32              13.51  43.653236,-79.376716
# 4             3           32               8.57  43.663722,-79.380288
# ..          ...          ...                ...                   ...
# 821           1           10               9.09  43.741906,-79.271819
# 822           8           11              42.11  43.736953,-79.247984
# 823           7           11              38.89  43.659457,-79.382365
# 824           4           11              26.67  43.705875,-79.368006
# 825           4           11              26.67  43.673489,-79.413395
#
# [826 rows x 8 columns]

# %%
csv_file_path = 'bike_stations_sat_3pm_clean.csv'
df_toronto.to_csv(csv_file_path, index=False)

# %% [markdown]
# **Data Obtained**
# - I have saved bike_stations_sat_3pm.csv and bike_stations_sat_3pm_clean to my github repository to save the data for prime time saturday afternoon as I feel the time of day/week does have an impact on bike availability that we will see in the model. I will try this with a less prime time such as monday early afternoon (everyone is at work) or tuesday morning (typically an "in-office" day in Toronto) to see if there's a noticeable difference
#
# - Data from bike stations at 1pm on Monday on a holiday weekend - the majority of establishments are closed in Toronto and the city is noticeably quieter than saturday (when the previous data was taken)

# %% [markdown]
# **Thoughts on Data viz**
# - The citybik.es website visualizes the occupancy of the stations on the front-end website, green with many bikes available, yellow has few bikes available and red has no bikes available. Visually there are a lot more greens in major downtown arteries than in the uptown and fringe areas.
# - We should look at an sns heat map of occupancy rate and see if it tracks to major downtown areas. The visualization should be latitude vs. Longitude with the colour of each dot representing the occupancy rate of the bike stations.
# - Lat/Long colour viz could be enhanced with size of the points indicating number of amenities returned by the Foursquare API call.
# - If we want, we could signpost major arteries in Toronto e.g. Yonge/King, Yonge/Bloor, Bathurst/College as we expect more traffic there than other places generally in Downtown
